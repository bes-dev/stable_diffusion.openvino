# %% [markdown]
# ### Stable Diffusion Starter Example

# %% [markdown]
# * Replace the prompt you'd like to use in the next cell. It'd take about 2 mins to create an image.

# %%
# !python demo.py --prompt "blueberry donut on the Moon, 3D realistic"
# Out:
# 32it [02:24,  4.50s/it]

# %% [markdown]
# * Generated image will be saved as `output.png`.

# %%
from IPython.display import Image
Image('/home/jovyan/stable_diffusion/output.png')
